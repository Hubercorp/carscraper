# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

df_auction = pd.read_csv('full_auction_cleaned.csv')
df_quote =  pd.read_csv('full_quote_cleaned.csv')

# %%
merged_inner = pd.merge(left=df_auction, right=df_quote, left_on='quote_id', right_on='quote_id')

# %%
merged_inner
# Out:
#      auction_brand  auction_date auction_location  \
# 0       ALFA ROMEO      20180118          PHOENIX
# 1       ALFA ROMEO      20060626          LONDRES
# 2       ALFA ROMEO      20161125            MILAN
# 3       ALFA ROMEO      20140206            PARIS
# 4       ALFA ROMEO      20070219            PARIS
# ...            ...           ...              ...
# 9899       TRIUMPH      20090703         GOODWOOD
# 9900       TRIUMPH      20070227          LONDRES
# 9901       TRIUMPH      20170902         BEAULIEU
# 9902       TRIUMPH      20060608       BROOKLANDS
# 9903       TRIUMPH      20190320          DUXFORD
#
#                                          auction_model  \
# 0                                   G 1 biplace course
# 1     6 C 1750 Turismo cabriolet James Young (0412349)
# 2                         6 C 2500 Freccia d'Oro coach
# 3                6 C 2500 Freccia d'Oro coach tout alu
# 4          6 C 2500 Sport Freccia d'Oro coach (916218)
# ...

# %%
merged_inner.to_csv("merged_inner_quote_auction.csv", encoding='utf-8', index=False)
